# %% [markdown]
# Credit Fraud Detection
#
# - Problem Statement -> Predict whether the person is defualter or non defaulter
#
# - Classification
#
# - Columns ->
#
# - Features ->
# - Target Variable ->
#
# - Model -> logistic, SVC, RandomForest,  XGBoost
# - Evaluation Metrics -> accuracy, precision, recall, confusion matrix, f1-score, roc-auc curve

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import tree
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import classification_report, roc_auc_score
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.corr()
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.135835e-16 -1.227819e-15 -9.215150e-16
# V2     -0.010593  4.135835e-16  1.000000e+00  3.243764e-16 -1.121065e-15
# V3     -0.419618 -1.227819e-15  3.243764e-16  1.000000e+00  4.711293e-16
# V4     -0.105260 -9.215150e-16 -1.121065e-15  4.711293e-16  1.000000e+00
# V5      0.173072  1.812612e-17  5.157519e-16 -6.539009e-17 -1.719944e-15
# V6     -0.063016 -6.506567e-16  2.787346e-16  1.627627e-15 -7.491959e-16
# V7      0.084714 -1.005191e-15  2.055934e-16  4.895305e-16 -4.104503e-16
# V8     -0.036949 -2.433822e-16 -5.377041e-17 -1.268779e-15  5.697192e-16
# V9     -0.008660 -1.513678e-16  1.978488e-17  5.568367e-16  6.923247e-16
# V10     0.030617  7.388135e-17 -3.991394e-16  1.156587e-15  2.232685e-16
# V11    -0.247689  2.125498e-16  1.975426e-16  1.576830e-15  3.459380e-16
# ...

# %%
sns. heatmap(df.corr(),)
# Out:
# <Axes: >

# %%
df["Class"].value_counts() # data is immbalance 0--> non defaulter , 1 --> defaulter
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
sns.displot(df['Amount'], bins=20)

# %%
df.skew()
# Out:
# Time      -0.035568
# V1        -3.280667
# V2        -4.624866
# V3        -2.240155
# V4         0.676292
# V5        -2.425901
# V6         1.826581
# V7         2.553907
# V8        -8.521944
# V9         0.554680
# V10        1.187141
# V11        0.356506
# V12       -2.278401
# V13        0.065233
# V14       -1.995176
# V15       -0.308423
# V16       -1.100966
# V17       -3.844914
# V18       -0.259880
# V19        0.109192
# V20       -2.037155
# V21        3.592991
# V22       -0.213258
# V23       -5.875140
# V24       -0.552499
# V25       -0.415793
# V26        0.576693
# V27       -1.170209
# V28       11.192091
# Amount    16.977724
# Class     23.997579
# dtype: float64

# %%
x = df.iloc[:, :-1] # feature
y = df.iloc[:,-1]# target

# %%
xtrain, xtest, ytrain, ytest =train_test_split(x,y, test_size=0.3, random_state=1,stratify=y)

# %%
logreg = LogisticRegression()
logreg.fit(xtrain,ytrain)
ypred = logreg.predict(xtest)

# %%
print(classification_report(ytest, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.81      0.68      0.74       148
#
#     accuracy                           1.00     85443
#    macro avg       0.90      0.84      0.87     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
rf = RandomForestClassifier(n_estimators=10, max_depth=7)
rf.fit(xtrain, ytrain)
ypred = rf.predict(xtest)

# %%
print(classification_report(ytest, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.93      0.84      0.88       148
#
#     accuracy                           1.00     85443
#    macro avg       0.97      0.92      0.94     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# Balance the Immbalance data

# %%
# pip install imblearn

# %%
from imblearn.over_sampling import SMOTE

# %%
sm =SMOTE()
xmoste,ymote = sm.fit_resample(xtrain,ytrain)

# %%
ymote.value_counts()
# Out:
# Class
# 0    199020
# 1    199020
# Name: count, dtype: int64

# %%
log_reg2 = LogisticRegression()
log_reg2.fit(xmoste, ymote)
ypred2 = log_reg2.predict(xtest)

# %%
print(classification_report(ytest, ypred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     85295
#            1       0.07      0.91      0.14       148
#
#     accuracy                           0.98     85443
#    macro avg       0.54      0.94      0.56     85443
# weighted avg       1.00      0.98      0.99     85443

# %%
rf2 = RandomForestClassifier(n_estimators=10, max_depth=7)
rf2.fit(xmoste, ymote)
ypred2 = rf2.predict(xtest)

# %%
print(classification_report(ytest, ypred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.34      0.90      0.50       148
#
#     accuracy                           1.00     85443
#    macro avg       0.67      0.95      0.75     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
rf2= RandomForestClassifier(n_estimators=10, max_depth=7)
rf2.fit(xmoste, ymote)
ypred2=rf2.predict(xtest)

# %%
print(classification_report(ytest, ypred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.29      0.89      0.44       148
#
#     accuracy                           1.00     85443
#    macro avg       0.65      0.94      0.72     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
svcscore= SVC()
svcscore.fit(xtrain, ytrain)
ypred3 = svcscore.predict(xtest)

# %%
print(classification_report(ytest, ypred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.00      0.00      0.00       148
#
#     accuracy                           1.00     85443
#    macro avg       0.50      0.50      0.50     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
svcscore2 = SVC()
svcscore2.fit(xmoste, ymote)
ypred4 = svcscore2.predict(xtest)

# %%
print(classification_report(ytest, ypred4))
